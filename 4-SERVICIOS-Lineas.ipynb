# %%
import pandas as pd

# %% [markdown]
# # Líneas de transporte de RMBA

# %% [markdown]
# ## Detalle de empresas de transporte que operan por Jurisdicción Municipal

# %%
municipal = pd.read_csv("https://servicios.transporte.gob.ar/gobierno_abierto/descargar.php?t=lineas&d=municipal", sep=";", encoding="UTF-8")
municipal
# Out:
#          anio jurisdiccion                                        Empresa  \
# 0     09/2019    MUNICIPAL  ALMAFUERTE EMPRESA DE TRANSPORTE S.A.C.I. E I
# 1     09/2019    MUNICIPAL  ALMAFUERTE EMPRESA DE TRANSPORTE S.A.C.I. E I
# 2     09/2019    MUNICIPAL    AUTOBUSES BS AS SRL- TTE LARRAZABAL SRL- UT
# 3     09/2019    MUNICIPAL                     AUTOBUSES BUENOS AIRES SRL
# 4     09/2019    MUNICIPAL                     AUTOBUSES BUENOS AIRES SRL
# ...       ...          ...                                            ...
# 5584  01/2016    MUNICIPAL                                     YITOS S.A.
# 5585  01/2016    MUNICIPAL                                     YITOS S.A.
# 5586  01/2016    MUNICIPAL                                     YITOS S.A.
# 5587  01/2016    MUNICIPAL                                     YITOS S.A.
# 5588  01/2016    MUNICIPAL                                     YITOS S.A.
#
#                linea
# 0          LINEA 622
# 1          LINEA 628
# ...

# %% [markdown]
# ## Detalle de empresas de transporte que operan por Jurisdicción Provincial

# %%
provincial = pd.read_csv("https://servicios.transporte.gob.ar/gobierno_abierto/descargar.php?t=lineas&d=provincial", sep=";", encoding="UTF-8")
provincial
# Out:
#          anio jurisdiccion                                        Empresa  \
# 0     09/2019   PROVINCIAL  ALMAFUERTE EMPRESA DE TRANSPORTE S.A.C.I. E I
# 1     09/2019   PROVINCIAL  ALMAFUERTE EMPRESA DE TRANSPORTE S.A.C.I. E I
# 2     09/2019   PROVINCIAL  ALMAFUERTE EMPRESA DE TRANSPORTE S.A.C.I. E I
# 3     09/2019   PROVINCIAL  ALMAFUERTE EMPRESA DE TRANSPORTE S.A.C.I. E I
# 4     09/2019   PROVINCIAL              AZUL S.A. DE TRANSPORTE AUTOMOTOR
# ...       ...          ...                                            ...
# 6235  01/2016   PROVINCIAL                    VILLA GALICIA SAN JOSE S.A.
# 6236  01/2016   PROVINCIAL                    VILLA GALICIA SAN JOSE S.A.
# 6237  01/2016   PROVINCIAL                    VILLA GALICIA SAN JOSE S.A.
# 6238  01/2016   PROVINCIAL                    VILLA GALICIA SAN JOSE S.A.
# 6239  01/2016   PROVINCIAL                               VILLA NUEVA S.A.
#
#              linea
# 0        LINEA 218
# 1        LINEA 284
# ...

# %% [markdown]
# ## Detalle de líneas de transporte que operan por Jurisdicción Nacional

# %%
nacional = pd.read_csv("https://servicios.transporte.gob.ar/gobierno_abierto/descargar.php?t=lineas&d=nacional", sep=";", encoding="UTF-8")
nacional
# Out:
#          anio jurisdiccion                                Empresa        linea
# 0     09/2019     NACIONAL                      17 DE AGOSTO S.A.     LINEA 26
# 1     09/2019     NACIONAL             4 DE SEPTIEMBRE S.A.T.C.P.     LINEA 37
# 2     09/2019     NACIONAL                ALMAFUERTE S.A.T.A.C.I.     LINEA 55
# 3     09/2019     NACIONAL      AZUL S.A. DE TRANSPORTE AUTOMOTOR     LINEA 41
# 4     09/2019     NACIONAL          BERNARDINO RIVADAVIA S.A.T.A.    LINEA 113
# ...       ...          ...                                    ...          ...
# 6793  01/2016     NACIONAL      TRANSPORTES QUIRNO COSTA S.A.C.I.  LINEA 103\r
# 6794  01/2016     NACIONAL       TRANSPORTES SOL DE MAYO C.I.S.A.    LINEA 4\r
# 6795  01/2016     NACIONAL           TRANSPORTES SUR NOR C.I.S.A.   LINEA 15\r
# 6796  01/2016     NACIONAL  UNION TRANSPORTISTAS DE EMPRESAS S.A.   LINEA 46\r
# 6797  01/2016     NACIONAL             VUELTA DE ROCHA S.A.T.C.I.   LINEA 64\r
#
# [6798 rows x 4 columns]
