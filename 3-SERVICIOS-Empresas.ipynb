# %%
import pandas as pd

# %% [markdown]
# # Empresas de transporte de RMBA

# %% [markdown]
# ## Detalle de empresas de transporte que operan Jurisdiccion Municipal

# %%
municipal = pd.read_csv("https://servicios.transporte.gob.ar/gobierno_abierto/descargar.php?t=empresas&d=municipal", sep=";", encoding="UTF-8")
municipal
# Out:
#          anio jurisdiccion                                            empresa
# 0     09/2019    MUNICIPAL      ALMAFUERTE EMPRESA DE TRANSPORTE S.A.C.I. E I
# 1     09/2019    MUNICIPAL        AUTOBUSES BS AS SRL- TTE LARRAZABAL SRL- UT
# 2     09/2019    MUNICIPAL                         AUTOBUSES BUENOS AIRES SRL
# 3     09/2019    MUNICIPAL  CIA ANDRADE EMPRESA DE TRANSPORTE DE PASAJEROS...
# 4     09/2019    MUNICIPAL           COMPAÑÍA DE OMNIBUS 25 DE MAYO LINEA 278
# ...       ...          ...                                                ...
# 2845  01/2016    MUNICIPAL                               UNION PLATENSE S.R.L
# 2846  01/2016    MUNICIPAL     UTENOR LINEA 722 UNION TRANSITORIA DE EMPRESAS
# 2847  01/2016    MUNICIPAL                        VILLA GALICIA SAN JOSE S.A.
# 2848  01/2016    MUNICIPAL                                   VILLA NUEVA S.A.
# 2849  01/2016    MUNICIPAL                                         YITOS S.A.
#
# [2850 rows x 3 columns]

# %% [markdown]
# ## Detalle de empresas de transporte que operan Jurisdiccion Nacional

# %%
nacional = pd.read_csv("https://servicios.transporte.gob.ar/gobierno_abierto/descargar.php?t=empresas&d=nacional", sep=";", encoding="UTF-8")
nacional
# Out:
#          anio jurisdiccion                                empresa
# 0     09/2019     NACIONAL                      17 DE AGOSTO S.A.
# 1     09/2019     NACIONAL             4 DE SEPTIEMBRE S.A.T.C.P.
# 2     09/2019     NACIONAL                ALMAFUERTE S.A.T.A.C.I.
# 3     09/2019     NACIONAL      AZUL S.A. DE TRANSPORTE AUTOMOTOR
# 4     09/2019     NACIONAL          BERNARDINO RIVADAVIA S.A.T.A.
# ...       ...          ...                                    ...
# 4107  01/2016     NACIONAL       TRANSPORTES SOL DE MAYO C.I.S.A.
# 4108  01/2016     NACIONAL           TRANSPORTES SUR NOR C.I.S.A.
# 4109  01/2016     NACIONAL  UNION TRANSPORTISTAS DE EMPRESAS S.A.
# 4110  01/2016     NACIONAL             VUELTA DE ROCHA S.A.T.C.I.
# 4111        /     NACIONAL                                    NaN
#
# [4112 rows x 3 columns]

# %% [markdown]
# ## Detalle de empresas de transporte que operan Jurisdiccion Provincial

# %%
provincial = pd.read_csv("https://servicios.transporte.gob.ar/gobierno_abierto/descargar.php?t=empresas&d=provincial", sep=";", encoding="UTF-8")
provincial
# Out:
#          anio jurisdiccion                                            empresa
# 0     09/2019   PROVINCIAL      ALMAFUERTE EMPRESA DE TRANSPORTE S.A.C.I. E I
# 1     09/2019   PROVINCIAL                  AZUL S.A. DE TRANSPORTE AUTOMOTOR
# 2     09/2019   PROVINCIAL  CIA ANDRADE EMPRESA DE TRANSPORTE DE PASAJEROS...
# 3     09/2019   PROVINCIAL                   CIA LA PAZ AMADOR MOURE SACIFIYA
# 4     09/2019   PROVINCIAL           COMPAÑÍA DE OMNIBUS 25 DE MAYO LINEA 278
# ...       ...          ...                                                ...
# 2589  01/2016   PROVINCIAL                        TRANSPORTES UNIDOS DE MERLO
# 2590  01/2016   PROVINCIAL                               UNION PLATENSE S.R.L
# 2591  01/2016   PROVINCIAL                              VILLA BOSCH S.A.C.E I
# 2592  01/2016   PROVINCIAL                        VILLA GALICIA SAN JOSE S.A.
# 2593  01/2016   PROVINCIAL                                   VILLA NUEVA S.A.
#
# [2594 rows x 3 columns]
